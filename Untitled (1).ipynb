# %%
Ana Beatriz De Carvalho Lopes
200034812

# %%
#exercicio 174:
def main():
    n = int(input("Digite n: "))
    m = int(input("Digite m: "))
    ant = n
    atual = m
    resto = atual % ant
    while resto != 0:
        resto = ant % atual
        ant = atual
        atual = resto

    print(" O Maior Divisor Comum de(%d,%d) é igual a %d" %(n,m,ant))
main()
# Out:
# Digite n:  495
# Digite m:  234
#  O Maior Divisor Comum de(495,234) é igual a 9

# %%
# exercicio 176:
palavras = {'A': 'Alpha', 'B': 'Bravo', 'C': 'Charlie', 'D': 'Delta', 'E': 'Echo',
         'F': 'Foxtrot', 'G': 'Golf', 'H': 'Hotel', 'I': 'India', 'J': 'Juliet',
         'K': 'Kilo', 'L': 'Lima', 'M': 'Mike', 'N': 'November', 'O': 'Oscar', 'P': 'Papa',
         'Q': 'Quebec', 'R': 'Romeo', 'S': 'Sierra', 'T': 'Tango', 'U': 'Uniform', 'V': 'Victor',
         'W': 'Whiskey', 'X': 'Xray', 'Y': 'Yankee', 'Z': 'Zulu'}

def alfabeto(p):
    if p == '':
        return ''

    else:
        if p[0].upper() in palavras.keys():
            return palavras[p[0].upper()] + ' ' + alfabeto(p[1:len(p)])
        else:
            return alfabeto(p[1:len(p)])

p = input('Palavra: ')
print(alfabeto(p))
# Out:
# Palavra:  hello
# Hotel Echo Lima Lima Oscar

# %%
#exercicio 177:
def romanos( cadeia):
  valor = { "0": 0, "I":1 , "V":5, "X":10, "L":50,"C":100,"M":1000 }
  acumulador_geral = 0
  anterior = "0"
  parcial = 0
  for algarismo in cadeia:
    if (algarismo == anterior):
      parcial += valor[algarismo]
    else:
       if (valor[algarismo]>valor[anterior]):
          acumulador_geral -= parcial
       else:
          acumulador_geral += parcial
       parcial = valor[algarismo]
       anterior = algarismo
  acumulador_geral += parcial
  return acumulador_geral

while True:
  romano = input("Informe um número em romanos")
  if (romano =="" ):
    break
  print(romanos(romano))
# Out:
# Informe um número em romanos MV
# 1005
